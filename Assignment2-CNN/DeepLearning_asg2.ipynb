# %%
from google.colab import drive
drive.mount('/content/gdrive')

import sys
sys.path.append('/content/gdrive/My Drive/Deep Learning/Assignment2')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import assignment
import preprocess
import assignment_tests
from importlib import reload
reload(assignment)
reload(preprocess)
reload(assignment_tests)
assignment.main('/content/gdrive/My Drive/Deep Learning/Assignment2/CIFAR_data/')
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-2-5cf87b37b463> in <module>()
#       6 reload(preprocess)
#       7 reload(assignment_tests)
# ----> 8 assignment.main('/content/gdrive/My Drive/Deep Learning/Assignment2/CIFAR_data/')
#
# /content/gdrive/My Drive/Deep Learning/Assignment2/assignment.py in main(cifar10_data_folder)
#     279
#     280   for epoch in range(25):
# --> 281     train(model, train_inputs, train_labels)
#     282
#     283   test_accuracy = test(model, test_inputs, test_labels)
#
# /content/gdrive/My Drive/Deep Learning/Assignment2/assignment.py in train(model, train_inputs, train_labels)
#     213         batch_inputs = np.reshape(batch_inputs, (model.batch_size, 32, 32, 3))
#     214         with tf.GradientTape() as tape:
# --> 215           logits = model.call(batch_inputs)
#     216           batch_loss = loss(logits, batch_labels)
# ...
